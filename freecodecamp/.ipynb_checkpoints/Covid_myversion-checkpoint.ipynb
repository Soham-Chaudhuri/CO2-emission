# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
df=pd.read_csv('D:\projects and languages-20220321T195543Z-001\projects and languages\dataset covid\country_wise_latest.csv')

# %%
df.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
df.drop(['New cases','New deaths','New recovered','WHO Region','Deaths / 100 Cases','Recovered / 100 Cases','Deaths / 100 Recovered','Confirmed last week','1 week change','1 week % increase'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active
# 0    Afghanistan      36263    1269      25198    9796
# 1        Albania       4880     144       2745    1991
# 2        Algeria      27973    1163      18837    7973
# 3        Andorra        907      52        803      52
# 4         Angola        950      41        242     667

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country/Region  187 non-null    object
#  1   Confirmed       187 non-null    int64
#  2   Deaths          187 non-null    int64
#  3   Recovered       187 non-null    int64
#  4   Active          187 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.4+ KB

# %%
df.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06

# %%
df2=df.groupby('Country/Region')[['Country/Region','Confirmed','Deaths','Recovered','Active']].sum().reset_index()

# %%
df2.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active
# 0    Afghanistan      36263    1269      25198    9796
# 1        Albania       4880     144       2745    1991
# 2        Algeria      27973    1163      18837    7973
# 3        Andorra        907      52        803      52
# 4         Angola        950      41        242     667

# %%
df3=df2[df2['Deaths']>10000]

# %%
df3.head()
# Out:
#    Country/Region  Confirmed  Deaths  Recovered  Active
# 23         Brazil    2442375   87618    1846641  508116
# 61         France     220352   30212      81212  108928
# 79          India    1480073   33408     951166  495499
# 81           Iran     293606   15912     255144   22550
# 85          Italy     246286   35112     198593   12581

# %%
df3.describe()
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 23 to 177
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country/Region  11 non-null     object
#  1   Confirmed       11 non-null     int64
#  2   Deaths          11 non-null     int64
#  3   Recovered       11 non-null     int64
#  4   Active          11 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 528.0+ bytes

# %%
plt.style.use('fivethirtyeight')

# %%
# plt.plot(df3['Country/Region'],df3['Deaths'])
# plt.plot(df3['Deaths'],df3['Country/Region'],linewidth=1)
# plt.rc('ytick', labelsize=20)
# plt.rc('xtick', labelsize=20)
# plt.tight_layout()
# plt.show()

# %%
df4=df3[df3['Country/Region']=='India']
# df4.values[0,2]
plt.plot(df['Deaths'],'k',label='Deaths',linewidth=1)
plt.show()
plt.plot(df['Active'],'k',label='Active',linewidth=1)
plt.show()
