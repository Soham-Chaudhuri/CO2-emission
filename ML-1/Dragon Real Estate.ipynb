# %% [markdown]
# # Dragon Real Estate Price Predictor

# %%
import pandas as pd

# %%
housing = pd.read_csv("data.csv")

# %%
housing.head()
# Out:
#     18  2.31  0  0.538  6.575  65.2    4.09  1  296  15.3   396.9  4.98    24  \
# 0  0.0  7.07  0  0.469  6.421  78.9  4.9671  2  242  17.8  396.90  9.14  21.6
# 1  0.0  7.07  0  0.469  7.185  61.1  4.9671  2  242  17.8  392.83  4.03  34.7
# 2  0.0  2.18  0  0.458  6.998  45.8  6.0622  3  222  18.7  394.63  2.94  33.4
# 3  0.0  2.18  0  0.458  7.147  54.2  6.0622  3  222  18.7  396.90  5.33  36.2
# 4  0.0  2.18  0  0.458  6.430  58.7  6.0622  3  222  18.7  394.12  5.21  28.7
#
#    Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  0.00632
# 0          NaN          NaN          NaN          NaN  0.02731
# 1          NaN          NaN          NaN          NaN  0.02729
# 2          NaN          NaN          NaN          NaN  0.03237
# 3          NaN          NaN          NaN          NaN  0.06905
# 4          NaN          NaN          NaN          NaN  0.02985

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   18           505 non-null    float64
#  1   2.31         505 non-null    float64
#  2   0            505 non-null    int64
#  3   0.538        505 non-null    float64
#  4   6.575        505 non-null    float64
#  5   65.2         505 non-null    float64
#  6   4.09         505 non-null    float64
#  7   1            505 non-null    int64
#  8   296          505 non-null    int64
#  9   15.3         505 non-null    float64
#  10  396.9        505 non-null    float64
#  11  4.98         505 non-null    float64
#  12  24           505 non-null    float64
#  13  Unnamed: 13  0 non-null      float64
#  14  Unnamed: 14  0 non-null      float64
#  15  Unnamed: 15  0 non-null      float64
#  16  Unnamed: 16  0 non-null      float64
#  17  0.00632      505 non-null    float64
# ...

# %%
housing.['18'].value_contents()
# Out:
#   Input In [7]
#     housing.['18'].value_contents()
#             ^
# SyntaxError: invalid syntax

# %%
housing['0'].value_counts()
# Out:
# 0    470
# 1     35
# Name: 0, dtype: int64

# %%
housing.describe()
# Out:
#                18        2.31           0       0.538       6.575        65.2  \
# count  505.000000  505.000000  505.000000  505.000000  505.000000  505.000000
# mean    11.350495   11.154257    0.069307    0.554728    6.284059   68.581584
# std     23.343704    6.855868    0.254227    0.115990    0.703195   28.176371
# min      0.000000    0.460000    0.000000    0.385000    3.561000    2.900000
# 25%      0.000000    5.190000    0.000000    0.449000    5.885000   45.000000
# 50%      0.000000    9.690000    0.000000    0.538000    6.208000   77.700000
# 75%     12.500000   18.100000    0.000000    0.624000    6.625000   94.100000
# max    100.000000   27.740000    1.000000    0.871000    8.780000  100.000000
#
#              4.09           1         296        15.3       396.9        4.98  \
# count  505.000000  505.000000  505.000000  505.000000  505.000000  505.000000
# mean     3.794459    9.566337  408.459406   18.461782  356.594376   12.668257
# ...

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
housing.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'18'}>,
#         <AxesSubplot:title={'center':'2.31'}>,
#         <AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'0.538'}>],
#        [<AxesSubplot:title={'center':'6.575'}>,
#         <AxesSubplot:title={'center':'65.2'}>,
#         <AxesSubplot:title={'center':'4.09'}>,
#         <AxesSubplot:title={'center':'1'}>],
#        [<AxesSubplot:title={'center':'296'}>,
#         <AxesSubplot:title={'center':'15.3'}>,
#         <AxesSubplot:title={'center':'396.9'}>,
#         <AxesSubplot:title={'center':'4.98'}>],
#        [<AxesSubplot:title={'center':'24'}>,
#         <AxesSubplot:title={'center':'Unnamed: 13'}>,
#         <AxesSubplot:title={'center':'Unnamed: 14'}>,
#         <AxesSubplot:title={'center':'Unnamed: 15'}>],
#        [<AxesSubplot:title={'center':'Unnamed: 16'}>,
#         <AxesSubplot:title={'center':'0.00632'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)
